# %%
import numpy as np
import matplotlib.pyplot as plt

from utils._tsne_analysis import get_tsne_results
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

plt.style.use('physrev_noticks.mplstyle')
plt.rcParams['figure.dpi'] = "300"

# %%
import os

import numpy as np
import pandas as pd
import scipy.io as sci
import torch
from tqdm import tqdm

from sklearn.manifold import TSNE

from utils._resnet import resnet18_8
from utils._preprocessing import _preprocessing

import plotly.express as px
import plotly.graph_objs as go
import matplotlib.pyplot as plt

# %%
for i in [1,2,3,4]:
    get_tsne_results(layer_num=i, verbose=False)
# Out:
# ./analysis_results/tsne_results/X1.npy
# Exist
# ./analysis_results/tsne_results/X2.npy
# Exist
# ./analysis_results/tsne_results/X3.npy
# Exist
# ./analysis_results/tsne_results/X4.npy
# Exist
