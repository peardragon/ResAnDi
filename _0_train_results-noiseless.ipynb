# %%
import numpy as np
import matplotlib.pyplot as plt

from utils._model_results import _get_model_results, _model_confidence_plot
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

plt.style.use('physrev_noticks.mplstyle')
plt.rcParams['figure.dpi'] = "300"

# %%
test_dataset = np.load("./dataset_noiseless/test/0.npy", allow_pickle=True)
model_name = "resnet18_8_b64_lr0.0001_noiseless"
model_results, ground_truth = _get_model_results(test_dataset, model_name, load=True, save=True)
# Out:
# Accuracy:  0.9035625

# %%
_model_confidence_plot(model_results, test_dataset)
# Out:
# /home/bjyong/ResAnDi/ResAnDi/utils/_model_results.py:114: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   predicted_counts = df.groupby(['Exponent', "Truth Label","Predicted Label"])["Predicted Label"].count()
# /home/bjyong/ResAnDi/ResAnDi/utils/_model_results.py:115: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   total_counts = df.groupby(['Exponent', "Truth Label"])["Truth Label"].count()
