# %%
import numpy as np
import matplotlib.pyplot as plt

from utils._augmentation import _save_augmentation_results, _augmentation_results

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

plt.style.use('physrev.mplstyle')
plt.rcParams['figure.dpi'] = "300"

# %%
_ = _save_augmentation_results()
# Out:
# Augmentation results for p=60 already exists at ./analysis_results/augmentation_results/p60_augmentation_results_noiseless.csv.
# Augmentation results for p=100 already exists at ./analysis_results/augmentation_results/p100_augmentation_results_noiseless.csv.

# %%
_augmentation_results()
